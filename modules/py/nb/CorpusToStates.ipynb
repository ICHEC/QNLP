# %% [markdown]
# # Convert corpus to non-zero state coefficients for quantum encoding

# %%
# Set the installation path of the intel-qnlp directory
QNLP_PATH="/Users/mlxd/workspace/quantum/intel-qnlp/"
corpus_name="jack_and_jill.txt"

# %%
# Load the module files assuming they are not on path
import importlib.util
spec = importlib.util.spec_from_file_location("tagging", QNLP_PATH+"py/tagging.py")
tg = importlib.util.module_from_spec(spec)
spec.loader.exec_module(tg)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9022f23a73f6> in <module>
#       3 spec = importlib.util.spec_from_file_location("tagging", QNLP_PATH+"py/tagging.py")
#       4 tg = importlib.util.module_from_spec(spec)
# ----> 5 spec.loader.exec_module(tg)
#
# ~/workspace/quantum/intel-qnlp/corpus/install/intel-qnlp_conda/envs/intel-qnlp/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/workspace/quantum/intel-qnlp/corpus/install/intel-qnlp_conda/envs/intel-qnlp/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# ~/workspace/quantum/intel-qnlp/corpus/install/intel-qnlp_conda/envs/intel-qnlp/lib/python3.7/importlib/_bootstrap_external.py in get_data(self, path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/mlxd/workspace/quantum/intel-qnlp/py/tagging.py'

# %%
import nltk
import sys
import numpy as np

from collections import Counter
from nltk.corpus import stopwords
sw = stopwords.words('english')

# %%
"""
Remove words that do not add to the meaning; simplifies sentences
"""
def remove_stopwords(text, sw):
    return [w for w in text if w not in sw]

# %%
"""
Pass the corpus as a string, which is subsequently broken into tokenised sentences, and returned as dictionary.
proc_mode defines whether to enable lemmatization (proc_mode="l") or stemming (proc_mode="s"). Stop words can 
also be removed by setting stop_words=False
"""
def tokenize_corpus(corpus, proc_mode=0, stop_words=True):
    token_sents = nltk.sent_tokenize(corpus_text) #Split on sentences
    token_words = [] # Individual words
    tags = [] # Words and respective tags

    for s in token_sents:
        tk = nltk.word_tokenize(s)
        if stop_words == False:
            tk = remove_stopwords(tk, sw)
        token_words.extend(tk)
        tags.extend(nltk.pos_tag(tk))

    if proc_mode != 0:
        if proc_mode == 's':
            s = nltk.SnowballStemmer('english', ignore_stopwords=True)
            token_words = [s.stem(t) for t in token_words]
        elif proc_mode == 'l':
            wnl = nltk.WordNetLemmatizer()
            token_words = [wnl.lemmatize(t) for t in token_words]

    tags = nltk.pos_tag(token_words)

    nouns = [i[0] for i in tags if tg.matchables(tg.Noun, i[1])]
    verbs = [i[0] for i in tags if tg.matchables(tg.Verb, i[1])]

    count_nouns = Counter(nouns)
    count_verbs = Counter(verbs)
    return {'verbs':count_verbs, 'nouns':count_nouns, 'tk_sentence':token_sents, 'tk_words':token_words}

# %%
# Load the corpus
corpus_text=""

with open(QNLP_PATH+"corpus/"+corpus_name, 'r') as corpusFile:
    corpus_text=corpusFile.read()

words = tokenize_corpus(corpus_text, proc_mode=0)

#Naively set sentence boundary at location of full-stops.
sentence_boundary = set([i for i, x in enumerate(words['tk_words']) if "." in x])

# %%
"""
Examine the words around each verb with the specified window size, and attempt to match the NVN pattern.
The window_size specifies the number of values around each verb to search for the matching nouns. If passed as tuple
(l,r) gives the left and right windows specarately. If passed as a scalar, both values are equal.
"""
def word_pairing(words, window_size):
    if type(window_size) is tuple:
        window_left, window_right = window_size
    else:
        window_left = window_size
        window_right = window_size
    verb_idx={}
    
    for v in words['verbs']:
        verb_idx.update({v:[i for i, x in enumerate(words['tk_words']) if v in x]})
    
    for n in words['nouns']:
        for v,k in verb_idx.items():
            for v_idx in k:
                #Ensure that no full stop appears over the windowed region to avoid crossing sentences.
                l_left = len(sentence_boundary.intersection(range(v_idx-window_left,v_idx)))
                l_right = len(sentence_boundary.intersection(range(v_idx,v_idx+window_right)))
                
                if l_left==0 and n in words['tk_words'][v_idx-window_left:v_idx]:
                    print("LEFT:=",n,v)
                if l_right==0 and (v_idx + window_right) < len(words['tk_words']) and n in words['tk_words'][v_idx:v_idx+window_right] :
                    print("RIGHT:=",v,n)

# %%
#window = (2,3)
window=1
word_pairing(words, window)
# Out:
# LEFT:= Jack fell
# LEFT:= Jack got
# LEFT:= Jill went
# LEFT:= Jill came
# LEFT:= home did

# %%
"""
Calculate the required number of qubits to encode the NVN state-space of the corpus.
Returns tuple of required states and number of needed qubits. 
While it is possible to reduce qubit count by considering the total required number as being the product of each combo, 
it is easier to deal with separate states for nouns and verbs, with at most 1 extra qubit required.
"""
def num_qubits(words):
    nvn_space_size = len(words['nouns'])**2 * len(words['verbs'])
    req_qubits_n = int(np.ceil(np.log2(len(words['nouns']))))
    req_qubits_v = int(np.ceil(np.log2(len(words['verbs']))))
    
    #req_qubits = int(np.ceil(np.log2(nvn_space_size)))
    req_qubits = req_qubits_n*2 + req_qubits_v
    
    print("Unique states:",nvn_space_size,"\tRequired qubits total:", req_qubits, \
          "\tRequired qubits nouns:", req_qubits_n, "\tRequired qubits verbs:", req_qubits_v)
    return (nvn_space_size, req_qubits, req_qubits_n, req_qubits_v)

# %%
_, num_q_total, num_q_n, num_q_v = num_qubits(words)
# Out:
# Unique states: 1584 	Required qubits total: 12 	Required qubits nouns: 4 	Required qubits verbs: 4

# %%
#The following pairings represent the intended meaning space. Many of these are non-sensicle combinations, and so
#the resulting data set will be sparse, with nonzero values for observed appearances from the windowed operation.
for i in words['nouns']:
    for j in words['verbs']:
        for k in words['nouns']:
            print(i," ", j, " ",k )
# Out:
# Jack   went   Jack
# Jack   went   Jill
# Jack   went   hill
# Jack   went   pail
# Jack   went   water
# Jack   went   crown
# Jack   went   Up
# Jack   went   home
# Jack   went   As
# Jack   went   head
# Jack   went   vinegar
# Jack   went   paper
# Jack   fetch   Jack
# Jack   fetch   Jill
# Jack   fetch   hill
# Jack   fetch   pail
# Jack   fetch   water
# Jack   fetch   crown
# Jack   fetch   Up
# Jack   fetch   home
# Jack   fetch   As
# Jack   fetch   head
# Jack   fetch   vinegar
# Jack   fetch   paper
# Jack   fell   Jack
# Jack   fell   Jill
# Jack   fell   hill
# Jack   fell   pail
# Jack   fell   water
# Jack   fell   crown
# Jack   fell   Up
# Jack   fell   home
# Jack   fell   As
# Jack   fell   head
# Jack   fell   vinegar
# Jack   fell   paper
# Jack   broke   Jack
# Jack   broke   Jill
# Jack   broke   hill
# Jack   broke   pail
# Jack   broke   water
# Jack   broke   crown
# Jack   broke   Up
# Jack   broke   home
# Jack   broke   As
# Jack   broke   head
# Jack   broke   vinegar
# Jack   broke   paper
# Jack   came   Jack
# Jack   came   Jill
# Jack   came   hill
# Jack   came   pail
# Jack   came   water
# Jack   came   crown
# Jack   came   Up
# Jack   came   home
# Jack   came   As
# Jack   came   head
# Jack   came   vinegar
# Jack   came   paper
# Jack   tumbling   Jack
# Jack   tumbling   Jill
# Jack   tumbling   hill
# Jack   tumbling   pail
# Jack   tumbling   water
# Jack   tumbling   crown
# Jack   tumbling   Up
# Jack   tumbling   home
# Jack   tumbling   As
# Jack   tumbling   head
# Jack   tumbling   vinegar
# Jack   tumbling   paper
# Jack   got   Jack
# Jack   got   Jill
# Jack   got   hill
# Jack   got   pail
# Jack   got   water
# Jack   got   crown
# Jack   got   Up
# Jack   got   home
# Jack   got   As
# Jack   got   head
# Jack   got   vinegar
# Jack   got   paper
# Jack   did   Jack
# Jack   did   Jill
# Jack   did   hill
# Jack   did   pail
# Jack   did   water
# Jack   did   crown
# Jack   did   Up
# Jack   did   home
# Jack   did   As
# Jack   did   head
# Jack   did   vinegar
# Jack   did   paper
# Jack   caper   Jack
# Jack   caper   Jill
# Jack   caper   hill
# Jack   caper   pail
# Jack   caper   water
# Jack   caper   crown
# Jack   caper   Up
# Jack   caper   home
# Jack   caper   As
# Jack   caper   head
# Jack   caper   vinegar
# Jack   caper   paper
# Jack   bed   Jack
# Jack   bed   Jill
# Jack   bed   hill
# Jack   bed   pail
# Jack   bed   water
# Jack   bed   crown
# Jack   bed   Up
# Jack   bed   home
# Jack   bed   As
# Jack   bed   head
# Jack   bed   vinegar
# Jack   bed   paper
# Jack   mend   Jack
# Jack   mend   Jill
# Jack   mend   hill
# Jack   mend   pail
# Jack   mend   water
# Jack   mend   crown
# Jack   mend   Up
# Jack   mend   home
# Jack   mend   As
# Jack   mend   head
# Jack   mend   vinegar
# Jack   mend   paper
# Jill   went   Jack
# Jill   went   Jill
# Jill   went   hill
# Jill   went   pail
# Jill   went   water
# Jill   went   crown
# Jill   went   Up
# Jill   went   home
# Jill   went   As
# Jill   went   head
# Jill   went   vinegar
# Jill   went   paper
# Jill   fetch   Jack
# Jill   fetch   Jill
# Jill   fetch   hill
# Jill   fetch   pail
# Jill   fetch   water
# Jill   fetch   crown
# Jill   fetch   Up
# Jill   fetch   home
# Jill   fetch   As
# Jill   fetch   head
# Jill   fetch   vinegar
# Jill   fetch   paper
# Jill   fell   Jack
# Jill   fell   Jill
# Jill   fell   hill
# Jill   fell   pail
# Jill   fell   water
# Jill   fell   crown
# Jill   fell   Up
# Jill   fell   home
# Jill   fell   As
# Jill   fell   head
# Jill   fell   vinegar
# Jill   fell   paper
# Jill   broke   Jack
# Jill   broke   Jill
# Jill   broke   hill
# Jill   broke   pail
# Jill   broke   water
# Jill   broke   crown
# Jill   broke   Up
# Jill   broke   home
# Jill   broke   As
# Jill   broke   head
# Jill   broke   vinegar
# Jill   broke   paper
# Jill   came   Jack
# Jill   came   Jill
# Jill   came   hill
# Jill   came   pail
# Jill   came   water
# Jill   came   crown
# Jill   came   Up
# Jill   came   home
# Jill   came   As
# Jill   came   head
# Jill   came   vinegar
# Jill   came   paper
# Jill   tumbling   Jack
# Jill   tumbling   Jill
# Jill   tumbling   hill
# Jill   tumbling   pail
# Jill   tumbling   water
# Jill   tumbling   crown
# Jill   tumbling   Up
# Jill   tumbling   home
# Jill   tumbling   As
# Jill   tumbling   head
# Jill   tumbling   vinegar
# Jill   tumbling   paper
# Jill   got   Jack
# Jill   got   Jill
# Jill   got   hill
# Jill   got   pail
# Jill   got   water
# Jill   got   crown
# Jill   got   Up
# Jill   got   home
# Jill   got   As
# Jill   got   head
# Jill   got   vinegar
# Jill   got   paper
# Jill   did   Jack
# Jill   did   Jill
# Jill   did   hill
# Jill   did   pail
# Jill   did   water
# Jill   did   crown
# Jill   did   Up
# Jill   did   home
# Jill   did   As
# Jill   did   head
# Jill   did   vinegar
# Jill   did   paper
# Jill   caper   Jack
# Jill   caper   Jill
# Jill   caper   hill
# Jill   caper   pail
# Jill   caper   water
# Jill   caper   crown
# Jill   caper   Up
# Jill   caper   home
# Jill   caper   As
# Jill   caper   head
# Jill   caper   vinegar
# Jill   caper   paper
# Jill   bed   Jack
# Jill   bed   Jill
# Jill   bed   hill
# Jill   bed   pail
# Jill   bed   water
# Jill   bed   crown
# Jill   bed   Up
# Jill   bed   home
# Jill   bed   As
# Jill   bed   head
# Jill   bed   vinegar
# Jill   bed   paper
# Jill   mend   Jack
# Jill   mend   Jill
# Jill   mend   hill
# Jill   mend   pail
# Jill   mend   water
# Jill   mend   crown
# Jill   mend   Up
# Jill   mend   home
# Jill   mend   As
# Jill   mend   head
# Jill   mend   vinegar
# Jill   mend   paper
# hill   went   Jack
# hill   went   Jill
# hill   went   hill
# hill   went   pail
# hill   went   water
# hill   went   crown
# hill   went   Up
# hill   went   home
# hill   went   As
# hill   went   head
# hill   went   vinegar
# hill   went   paper
# hill   fetch   Jack
# hill   fetch   Jill
# hill   fetch   hill
# hill   fetch   pail
# hill   fetch   water
# hill   fetch   crown
# hill   fetch   Up
# hill   fetch   home
# hill   fetch   As
# hill   fetch   head
# hill   fetch   vinegar
# hill   fetch   paper
# hill   fell   Jack
# hill   fell   Jill
# hill   fell   hill
# hill   fell   pail
# hill   fell   water
# hill   fell   crown
# hill   fell   Up
# hill   fell   home
# hill   fell   As
# hill   fell   head
# hill   fell   vinegar
# hill   fell   paper
# hill   broke   Jack
# hill   broke   Jill
# hill   broke   hill
# hill   broke   pail
# hill   broke   water
# hill   broke   crown
# hill   broke   Up
# hill   broke   home
# hill   broke   As
# hill   broke   head
# hill   broke   vinegar
# hill   broke   paper
# hill   came   Jack
# hill   came   Jill
# hill   came   hill
# hill   came   pail
# hill   came   water
# hill   came   crown
# hill   came   Up
# hill   came   home
# hill   came   As
# hill   came   head
# hill   came   vinegar
# hill   came   paper
# hill   tumbling   Jack
# hill   tumbling   Jill
# hill   tumbling   hill
# hill   tumbling   pail
# hill   tumbling   water
# hill   tumbling   crown
# hill   tumbling   Up
# hill   tumbling   home
# hill   tumbling   As
# hill   tumbling   head
# hill   tumbling   vinegar
# hill   tumbling   paper
# hill   got   Jack
# hill   got   Jill
# hill   got   hill
# hill   got   pail
# hill   got   water
# hill   got   crown
# hill   got   Up
# hill   got   home
# hill   got   As
# hill   got   head
# hill   got   vinegar
# hill   got   paper
# hill   did   Jack
# hill   did   Jill
# hill   did   hill
# hill   did   pail
# hill   did   water
# hill   did   crown
# hill   did   Up
# hill   did   home
# hill   did   As
# hill   did   head
# hill   did   vinegar
# hill   did   paper
# hill   caper   Jack
# hill   caper   Jill
# hill   caper   hill
# hill   caper   pail
# hill   caper   water
# hill   caper   crown
# hill   caper   Up
# hill   caper   home
# hill   caper   As
# hill   caper   head
# hill   caper   vinegar
# hill   caper   paper
# hill   bed   Jack
# hill   bed   Jill
# hill   bed   hill
# hill   bed   pail
# hill   bed   water
# hill   bed   crown
# hill   bed   Up
# hill   bed   home
# hill   bed   As
# hill   bed   head
# hill   bed   vinegar
# hill   bed   paper
# hill   mend   Jack
# hill   mend   Jill
# hill   mend   hill
# hill   mend   pail
# hill   mend   water
# hill   mend   crown
# hill   mend   Up
# hill   mend   home
# hill   mend   As
# hill   mend   head
# hill   mend   vinegar
# hill   mend   paper
# pail   went   Jack
# pail   went   Jill
# pail   went   hill
# pail   went   pail
# pail   went   water
# pail   went   crown
# pail   went   Up
# pail   went   home
# pail   went   As
# pail   went   head
# pail   went   vinegar
# pail   went   paper
# pail   fetch   Jack
# pail   fetch   Jill
# pail   fetch   hill
# pail   fetch   pail
# pail   fetch   water
# pail   fetch   crown
# pail   fetch   Up
# pail   fetch   home
# pail   fetch   As
# pail   fetch   head
# pail   fetch   vinegar
# pail   fetch   paper
# pail   fell   Jack
# pail   fell   Jill
# pail   fell   hill
# pail   fell   pail
# pail   fell   water
# pail   fell   crown
# pail   fell   Up
# pail   fell   home
# pail   fell   As
# pail   fell   head
# pail   fell   vinegar
# pail   fell   paper
# pail   broke   Jack
# pail   broke   Jill
# pail   broke   hill
# pail   broke   pail
# pail   broke   water
# pail   broke   crown
# pail   broke   Up
# pail   broke   home
# pail   broke   As
# pail   broke   head
# pail   broke   vinegar
# pail   broke   paper
# pail   came   Jack
# pail   came   Jill
# pail   came   hill
# pail   came   pail
# pail   came   water
# pail   came   crown
# pail   came   Up
# pail   came   home
# pail   came   As
# pail   came   head
# pail   came   vinegar
# pail   came   paper
# pail   tumbling   Jack
# pail   tumbling   Jill
# pail   tumbling   hill
# pail   tumbling   pail
# pail   tumbling   water
# pail   tumbling   crown
# pail   tumbling   Up
# pail   tumbling   home
# pail   tumbling   As
# pail   tumbling   head
# pail   tumbling   vinegar
# pail   tumbling   paper
# pail   got   Jack
# pail   got   Jill
# pail   got   hill
# pail   got   pail
# pail   got   water
# pail   got   crown
# pail   got   Up
# pail   got   home
# pail   got   As
# pail   got   head
# pail   got   vinegar
# pail   got   paper
# pail   did   Jack
# pail   did   Jill
# pail   did   hill
# pail   did   pail
# pail   did   water
# pail   did   crown
# pail   did   Up
# pail   did   home
# pail   did   As
# pail   did   head
# pail   did   vinegar
# pail   did   paper
# pail   caper   Jack
# pail   caper   Jill
# pail   caper   hill
# pail   caper   pail
# pail   caper   water
# pail   caper   crown
# pail   caper   Up
# pail   caper   home
# pail   caper   As
# pail   caper   head
# pail   caper   vinegar
# pail   caper   paper
# pail   bed   Jack
# pail   bed   Jill
# pail   bed   hill
# pail   bed   pail
# pail   bed   water
# pail   bed   crown
# pail   bed   Up
# pail   bed   home
# pail   bed   As
# pail   bed   head
# pail   bed   vinegar
# pail   bed   paper
# pail   mend   Jack
# pail   mend   Jill
# pail   mend   hill
# pail   mend   pail
# pail   mend   water
# pail   mend   crown
# pail   mend   Up
# pail   mend   home
# pail   mend   As
# pail   mend   head
# pail   mend   vinegar
# pail   mend   paper
# water   went   Jack
# water   went   Jill
# water   went   hill
# water   went   pail
# water   went   water
# water   went   crown
# water   went   Up
# water   went   home
# water   went   As
# water   went   head
# water   went   vinegar
# water   went   paper
# water   fetch   Jack
# water   fetch   Jill
# water   fetch   hill
# water   fetch   pail
# water   fetch   water
# water   fetch   crown
# water   fetch   Up
# water   fetch   home
# water   fetch   As
# water   fetch   head
# water   fetch   vinegar
# water   fetch   paper
# water   fell   Jack
# water   fell   Jill
# water   fell   hill
# water   fell   pail
# water   fell   water
# water   fell   crown
# water   fell   Up
# water   fell   home
# water   fell   As
# water   fell   head
# water   fell   vinegar
# water   fell   paper
# water   broke   Jack
# water   broke   Jill
# water   broke   hill
# water   broke   pail
# water   broke   water
# water   broke   crown
# water   broke   Up
# water   broke   home
# water   broke   As
# water   broke   head
# water   broke   vinegar
# water   broke   paper
# water   came   Jack
# water   came   Jill
# water   came   hill
# water   came   pail
# water   came   water
# water   came   crown
# water   came   Up
# water   came   home
# water   came   As
# water   came   head
# water   came   vinegar
# water   came   paper
# water   tumbling   Jack
# water   tumbling   Jill
# water   tumbling   hill
# water   tumbling   pail
# water   tumbling   water
# water   tumbling   crown
# water   tumbling   Up
# water   tumbling   home
# water   tumbling   As
# water   tumbling   head
# water   tumbling   vinegar
# water   tumbling   paper
# water   got   Jack
# water   got   Jill
# water   got   hill
# water   got   pail
# water   got   water
# water   got   crown
# water   got   Up
# water   got   home
# water   got   As
# water   got   head
# water   got   vinegar
# water   got   paper
# water   did   Jack
# water   did   Jill
# water   did   hill
# water   did   pail
# water   did   water
# water   did   crown
# water   did   Up
# water   did   home
# water   did   As
# water   did   head
# water   did   vinegar
# water   did   paper
# water   caper   Jack
# water   caper   Jill
# water   caper   hill
# water   caper   pail
# water   caper   water
# water   caper   crown
# water   caper   Up
# water   caper   home
# water   caper   As
# water   caper   head
# water   caper   vinegar
# water   caper   paper
# water   bed   Jack
# water   bed   Jill
# water   bed   hill
# water   bed   pail
# water   bed   water
# water   bed   crown
# water   bed   Up
# water   bed   home
# water   bed   As
# water   bed   head
# water   bed   vinegar
# water   bed   paper
# water   mend   Jack
# water   mend   Jill
# water   mend   hill
# water   mend   pail
# water   mend   water
# water   mend   crown
# water   mend   Up
# water   mend   home
# water   mend   As
# water   mend   head
# water   mend   vinegar
# water   mend   paper
# crown   went   Jack
# crown   went   Jill
# crown   went   hill
# crown   went   pail
# crown   went   water
# crown   went   crown
# crown   went   Up
# crown   went   home
# crown   went   As
# crown   went   head
# crown   went   vinegar
# crown   went   paper
# crown   fetch   Jack
# crown   fetch   Jill
# crown   fetch   hill
# crown   fetch   pail
# crown   fetch   water
# crown   fetch   crown
# crown   fetch   Up
# crown   fetch   home
# crown   fetch   As
# crown   fetch   head
# crown   fetch   vinegar
# crown   fetch   paper
# crown   fell   Jack
# crown   fell   Jill
# crown   fell   hill
# crown   fell   pail
# crown   fell   water
# crown   fell   crown
# crown   fell   Up
# crown   fell   home
# crown   fell   As
# crown   fell   head
# crown   fell   vinegar
# crown   fell   paper
# crown   broke   Jack
# crown   broke   Jill
# crown   broke   hill
# crown   broke   pail
# crown   broke   water
# crown   broke   crown
# crown   broke   Up
# crown   broke   home
# crown   broke   As
# crown   broke   head
# crown   broke   vinegar
# crown   broke   paper
# crown   came   Jack
# crown   came   Jill
# crown   came   hill
# crown   came   pail
# crown   came   water
# crown   came   crown
# crown   came   Up
# crown   came   home
# crown   came   As
# crown   came   head
# crown   came   vinegar
# crown   came   paper
# crown   tumbling   Jack
# crown   tumbling   Jill
# crown   tumbling   hill
# crown   tumbling   pail
# crown   tumbling   water
# crown   tumbling   crown
# crown   tumbling   Up
# crown   tumbling   home
# crown   tumbling   As
# crown   tumbling   head
# crown   tumbling   vinegar
# crown   tumbling   paper
# crown   got   Jack
# crown   got   Jill
# crown   got   hill
# crown   got   pail
# crown   got   water
# crown   got   crown
# crown   got   Up
# crown   got   home
# crown   got   As
# crown   got   head
# crown   got   vinegar
# crown   got   paper
# crown   did   Jack
# crown   did   Jill
# crown   did   hill
# crown   did   pail
# crown   did   water
# crown   did   crown
# crown   did   Up
# crown   did   home
# crown   did   As
# crown   did   head
# crown   did   vinegar
# crown   did   paper
# crown   caper   Jack
# crown   caper   Jill
# crown   caper   hill
# crown   caper   pail
# crown   caper   water
# crown   caper   crown
# crown   caper   Up
# crown   caper   home
# crown   caper   As
# crown   caper   head
# crown   caper   vinegar
# crown   caper   paper
# crown   bed   Jack
# crown   bed   Jill
# crown   bed   hill
# crown   bed   pail
# crown   bed   water
# crown   bed   crown
# crown   bed   Up
# crown   bed   home
# crown   bed   As
# crown   bed   head
# crown   bed   vinegar
# crown   bed   paper
# crown   mend   Jack
# crown   mend   Jill
# crown   mend   hill
# crown   mend   pail
# crown   mend   water
# crown   mend   crown
# crown   mend   Up
# crown   mend   home
# crown   mend   As
# crown   mend   head
# crown   mend   vinegar
# crown   mend   paper
# Up   went   Jack
# Up   went   Jill
# Up   went   hill
# Up   went   pail
# Up   went   water
# Up   went   crown
# Up   went   Up
# Up   went   home
# Up   went   As
# Up   went   head
# Up   went   vinegar
# Up   went   paper
# Up   fetch   Jack
# Up   fetch   Jill
# Up   fetch   hill
# Up   fetch   pail
# Up   fetch   water
# Up   fetch   crown
# Up   fetch   Up
# Up   fetch   home
# Up   fetch   As
# Up   fetch   head
# Up   fetch   vinegar
# Up   fetch   paper
# Up   fell   Jack
# Up   fell   Jill
# Up   fell   hill
# Up   fell   pail
# Up   fell   water
# Up   fell   crown
# Up   fell   Up
# Up   fell   home
# Up   fell   As
# Up   fell   head
# Up   fell   vinegar
# Up   fell   paper
# Up   broke   Jack
# Up   broke   Jill
# Up   broke   hill
# Up   broke   pail
# Up   broke   water
# Up   broke   crown
# Up   broke   Up
# Up   broke   home
# Up   broke   As
# Up   broke   head
# Up   broke   vinegar
# Up   broke   paper
# Up   came   Jack
# Up   came   Jill
# Up   came   hill
# Up   came   pail
# Up   came   water
# Up   came   crown
# Up   came   Up
# Up   came   home
# Up   came   As
# Up   came   head
# Up   came   vinegar
# Up   came   paper
# Up   tumbling   Jack
# Up   tumbling   Jill
# Up   tumbling   hill
# Up   tumbling   pail
# Up   tumbling   water
# Up   tumbling   crown
# Up   tumbling   Up
# Up   tumbling   home
# Up   tumbling   As
# Up   tumbling   head
# Up   tumbling   vinegar
# Up   tumbling   paper
# Up   got   Jack
# Up   got   Jill
# Up   got   hill
# Up   got   pail
# Up   got   water
# Up   got   crown
# Up   got   Up
# Up   got   home
# Up   got   As
# Up   got   head
# Up   got   vinegar
# Up   got   paper
# Up   did   Jack
# Up   did   Jill
# Up   did   hill
# Up   did   pail
# Up   did   water
# Up   did   crown
# Up   did   Up
# Up   did   home
# Up   did   As
# Up   did   head
# Up   did   vinegar
# Up   did   paper
# Up   caper   Jack
# Up   caper   Jill
# Up   caper   hill
# Up   caper   pail
# Up   caper   water
# Up   caper   crown
# Up   caper   Up
# Up   caper   home
# Up   caper   As
# Up   caper   head
# Up   caper   vinegar
# Up   caper   paper
# Up   bed   Jack
# Up   bed   Jill
# Up   bed   hill
# Up   bed   pail
# Up   bed   water
# Up   bed   crown
# Up   bed   Up
# Up   bed   home
# Up   bed   As
# Up   bed   head
# Up   bed   vinegar
# Up   bed   paper
# Up   mend   Jack
# Up   mend   Jill
# Up   mend   hill
# Up   mend   pail
# Up   mend   water
# Up   mend   crown
# Up   mend   Up
# Up   mend   home
# Up   mend   As
# Up   mend   head
# Up   mend   vinegar
# Up   mend   paper
# home   went   Jack
# home   went   Jill
# home   went   hill
# home   went   pail
# home   went   water
# home   went   crown
# home   went   Up
# home   went   home
# home   went   As
# home   went   head
# home   went   vinegar
# home   went   paper
# home   fetch   Jack
# home   fetch   Jill
# home   fetch   hill
# home   fetch   pail
# home   fetch   water
# home   fetch   crown
# home   fetch   Up
# home   fetch   home
# home   fetch   As
# home   fetch   head
# home   fetch   vinegar
# home   fetch   paper
# home   fell   Jack
# home   fell   Jill
# home   fell   hill
# home   fell   pail
# home   fell   water
# home   fell   crown
# home   fell   Up
# home   fell   home
# home   fell   As
# home   fell   head
# home   fell   vinegar
# home   fell   paper
# home   broke   Jack
# home   broke   Jill
# home   broke   hill
# home   broke   pail
# home   broke   water
# home   broke   crown
# home   broke   Up
# home   broke   home
# home   broke   As
# home   broke   head
# home   broke   vinegar
# home   broke   paper
# home   came   Jack
# home   came   Jill
# home   came   hill
# home   came   pail
# home   came   water
# home   came   crown
# home   came   Up
# home   came   home
# home   came   As
# home   came   head
# home   came   vinegar
# home   came   paper
# home   tumbling   Jack
# home   tumbling   Jill
# home   tumbling   hill
# home   tumbling   pail
# home   tumbling   water
# home   tumbling   crown
# home   tumbling   Up
# home   tumbling   home
# home   tumbling   As
# home   tumbling   head
# home   tumbling   vinegar
# home   tumbling   paper
# home   got   Jack
# home   got   Jill
# home   got   hill
# home   got   pail
# home   got   water
# home   got   crown
# home   got   Up
# home   got   home
# home   got   As
# home   got   head
# home   got   vinegar
# home   got   paper
# home   did   Jack
# home   did   Jill
# home   did   hill
# home   did   pail
# home   did   water
# home   did   crown
# home   did   Up
# home   did   home
# home   did   As
# home   did   head
# home   did   vinegar
# home   did   paper
# home   caper   Jack
# home   caper   Jill
# home   caper   hill
# home   caper   pail
# home   caper   water
# home   caper   crown
# home   caper   Up
# home   caper   home
# home   caper   As
# home   caper   head
# home   caper   vinegar
# home   caper   paper
# home   bed   Jack
# home   bed   Jill
# home   bed   hill
# home   bed   pail
# home   bed   water
# home   bed   crown
# home   bed   Up
# home   bed   home
# home   bed   As
# home   bed   head
# home   bed   vinegar
# home   bed   paper
# home   mend   Jack
# home   mend   Jill
# home   mend   hill
# home   mend   pail
# home   mend   water
# home   mend   crown
# home   mend   Up
# home   mend   home
# home   mend   As
# home   mend   head
# home   mend   vinegar
# home   mend   paper
# As   went   Jack
# As   went   Jill
# As   went   hill
# As   went   pail
# As   went   water
# As   went   crown
# As   went   Up
# As   went   home
# As   went   As
# As   went   head
# As   went   vinegar
# As   went   paper
# As   fetch   Jack
# As   fetch   Jill
# As   fetch   hill
# As   fetch   pail
# As   fetch   water
# As   fetch   crown
# As   fetch   Up
# As   fetch   home
# As   fetch   As
# As   fetch   head
# As   fetch   vinegar
# As   fetch   paper
# As   fell   Jack
# As   fell   Jill
# As   fell   hill
# As   fell   pail
# As   fell   water
# As   fell   crown
# As   fell   Up
# As   fell   home
# As   fell   As
# As   fell   head
# As   fell   vinegar
# As   fell   paper
# As   broke   Jack
# As   broke   Jill
# As   broke   hill
# As   broke   pail
# As   broke   water
# As   broke   crown
# As   broke   Up
# As   broke   home
# As   broke   As
# As   broke   head
# As   broke   vinegar
# As   broke   paper
# As   came   Jack
# As   came   Jill
# As   came   hill
# As   came   pail
# As   came   water
# As   came   crown
# As   came   Up
# As   came   home
# As   came   As
# As   came   head
# As   came   vinegar
# As   came   paper
# As   tumbling   Jack
# As   tumbling   Jill
# As   tumbling   hill
# As   tumbling   pail
# As   tumbling   water
# As   tumbling   crown
# As   tumbling   Up
# As   tumbling   home
# As   tumbling   As
# As   tumbling   head
# As   tumbling   vinegar
# As   tumbling   paper
# As   got   Jack
# As   got   Jill
# As   got   hill
# As   got   pail
# As   got   water
# As   got   crown
# As   got   Up
# As   got   home
# As   got   As
# As   got   head
# As   got   vinegar
# As   got   paper
# As   did   Jack
# As   did   Jill
# As   did   hill
# As   did   pail
# As   did   water
# As   did   crown
# As   did   Up
# As   did   home
# As   did   As
# As   did   head
# As   did   vinegar
# As   did   paper
# As   caper   Jack
# As   caper   Jill
# As   caper   hill
# As   caper   pail
# As   caper   water
# As   caper   crown
# As   caper   Up
# As   caper   home
# As   caper   As
# As   caper   head
# As   caper   vinegar
# As   caper   paper
# As   bed   Jack
# As   bed   Jill
# As   bed   hill
# As   bed   pail
# As   bed   water
# As   bed   crown
# As   bed   Up
# As   bed   home
# As   bed   As
# As   bed   head
# As   bed   vinegar
# As   bed   paper
# As   mend   Jack
# As   mend   Jill
# As   mend   hill
# As   mend   pail
# As   mend   water
# As   mend   crown
# As   mend   Up
# As   mend   home
# As   mend   As
# As   mend   head
# As   mend   vinegar
# As   mend   paper
# head   went   Jack
# head   went   Jill
# head   went   hill
# head   went   pail
# head   went   water
# head   went   crown
# head   went   Up
# head   went   home
# head   went   As
# head   went   head
# head   went   vinegar
# head   went   paper
# head   fetch   Jack
# head   fetch   Jill
# head   fetch   hill
# head   fetch   pail
# head   fetch   water
# head   fetch   crown
# head   fetch   Up
# head   fetch   home
# head   fetch   As
# head   fetch   head
# head   fetch   vinegar
# head   fetch   paper
# head   fell   Jack
# head   fell   Jill
# head   fell   hill
# head   fell   pail
# head   fell   water
# head   fell   crown
# head   fell   Up
# head   fell   home
# head   fell   As
# head   fell   head
# head   fell   vinegar
# head   fell   paper
# head   broke   Jack
# head   broke   Jill
# head   broke   hill
# head   broke   pail
# head   broke   water
# head   broke   crown
# head   broke   Up
# head   broke   home
# head   broke   As
# head   broke   head
# head   broke   vinegar
# head   broke   paper
# head   came   Jack
# head   came   Jill
# head   came   hill
# head   came   pail
# head   came   water
# head   came   crown
# head   came   Up
# head   came   home
# head   came   As
# head   came   head
# head   came   vinegar
# head   came   paper
# head   tumbling   Jack
# head   tumbling   Jill
# head   tumbling   hill
# head   tumbling   pail
# head   tumbling   water
# head   tumbling   crown
# head   tumbling   Up
# head   tumbling   home
# head   tumbling   As
# head   tumbling   head
# head   tumbling   vinegar
# head   tumbling   paper
# head   got   Jack
# head   got   Jill
# head   got   hill
# head   got   pail
# head   got   water
# head   got   crown
# head   got   Up
# head   got   home
# head   got   As
# head   got   head
# head   got   vinegar
# head   got   paper
# head   did   Jack
# head   did   Jill
# head   did   hill
# head   did   pail
# head   did   water
# head   did   crown
# head   did   Up
# head   did   home
# head   did   As
# head   did   head
# head   did   vinegar
# head   did   paper
# head   caper   Jack
# head   caper   Jill
# head   caper   hill
# head   caper   pail
# head   caper   water
# head   caper   crown
# head   caper   Up
# head   caper   home
# head   caper   As
# head   caper   head
# head   caper   vinegar
# head   caper   paper
# head   bed   Jack
# head   bed   Jill
# head   bed   hill
# head   bed   pail
# head   bed   water
# head   bed   crown
# head   bed   Up
# head   bed   home
# head   bed   As
# head   bed   head
# head   bed   vinegar
# head   bed   paper
# head   mend   Jack
# head   mend   Jill
# head   mend   hill
# head   mend   pail
# head   mend   water
# head   mend   crown
# head   mend   Up
# head   mend   home
# head   mend   As
# head   mend   head
# head   mend   vinegar
# head   mend   paper
# vinegar   went   Jack
# vinegar   went   Jill
# vinegar   went   hill
# vinegar   went   pail
# vinegar   went   water
# vinegar   went   crown
# vinegar   went   Up
# vinegar   went   home
# vinegar   went   As
# vinegar   went   head
# vinegar   went   vinegar
# vinegar   went   paper
# vinegar   fetch   Jack
# vinegar   fetch   Jill
# vinegar   fetch   hill
# vinegar   fetch   pail
# vinegar   fetch   water
# vinegar   fetch   crown
# vinegar   fetch   Up
# vinegar   fetch   home
# vinegar   fetch   As
# vinegar   fetch   head
# vinegar   fetch   vinegar
# vinegar   fetch   paper
# vinegar   fell   Jack
# vinegar   fell   Jill
# vinegar   fell   hill
# vinegar   fell   pail
# vinegar   fell   water
# vinegar   fell   crown
# vinegar   fell   Up
# vinegar   fell   home
# vinegar   fell   As
# vinegar   fell   head
# vinegar   fell   vinegar
# vinegar   fell   paper
# vinegar   broke   Jack
# vinegar   broke   Jill
# vinegar   broke   hill
# vinegar   broke   pail
# vinegar   broke   water
# vinegar   broke   crown
# vinegar   broke   Up
# vinegar   broke   home
# vinegar   broke   As
# vinegar   broke   head
# vinegar   broke   vinegar
# vinegar   broke   paper
# vinegar   came   Jack
# vinegar   came   Jill
# vinegar   came   hill
# vinegar   came   pail
# vinegar   came   water
# vinegar   came   crown
# vinegar   came   Up
# vinegar   came   home
# vinegar   came   As
# vinegar   came   head
# vinegar   came   vinegar
# vinegar   came   paper
# vinegar   tumbling   Jack
# vinegar   tumbling   Jill
# vinegar   tumbling   hill
# vinegar   tumbling   pail
# vinegar   tumbling   water
# vinegar   tumbling   crown
# vinegar   tumbling   Up
# vinegar   tumbling   home
# vinegar   tumbling   As
# vinegar   tumbling   head
# vinegar   tumbling   vinegar
# vinegar   tumbling   paper
# vinegar   got   Jack
# vinegar   got   Jill
# vinegar   got   hill
# vinegar   got   pail
# vinegar   got   water
# vinegar   got   crown
# vinegar   got   Up
# vinegar   got   home
# vinegar   got   As
# vinegar   got   head
# vinegar   got   vinegar
# vinegar   got   paper
# vinegar   did   Jack
# vinegar   did   Jill
# vinegar   did   hill
# vinegar   did   pail
# vinegar   did   water
# vinegar   did   crown
# vinegar   did   Up
# vinegar   did   home
# vinegar   did   As
# vinegar   did   head
# vinegar   did   vinegar
# vinegar   did   paper
# vinegar   caper   Jack
# vinegar   caper   Jill
# vinegar   caper   hill
# vinegar   caper   pail
# vinegar   caper   water
# vinegar   caper   crown
# vinegar   caper   Up
# vinegar   caper   home
# vinegar   caper   As
# vinegar   caper   head
# vinegar   caper   vinegar
# vinegar   caper   paper
# vinegar   bed   Jack
# vinegar   bed   Jill
# vinegar   bed   hill
# vinegar   bed   pail
# vinegar   bed   water
# vinegar   bed   crown
# vinegar   bed   Up
# vinegar   bed   home
# vinegar   bed   As
# vinegar   bed   head
# vinegar   bed   vinegar
# vinegar   bed   paper
# vinegar   mend   Jack
# vinegar   mend   Jill
# vinegar   mend   hill
# vinegar   mend   pail
# vinegar   mend   water
# vinegar   mend   crown
# vinegar   mend   Up
# vinegar   mend   home
# vinegar   mend   As
# vinegar   mend   head
# vinegar   mend   vinegar
# vinegar   mend   paper
# paper   went   Jack
# paper   went   Jill
# paper   went   hill
# paper   went   pail
# paper   went   water
# paper   went   crown
# paper   went   Up
# paper   went   home
# paper   went   As
# paper   went   head
# paper   went   vinegar
# paper   went   paper
# paper   fetch   Jack
# paper   fetch   Jill
# paper   fetch   hill
# paper   fetch   pail
# paper   fetch   water
# paper   fetch   crown
# paper   fetch   Up
# paper   fetch   home
# paper   fetch   As
# paper   fetch   head
# paper   fetch   vinegar
# paper   fetch   paper
# paper   fell   Jack
# paper   fell   Jill
# paper   fell   hill
# paper   fell   pail
# paper   fell   water
# paper   fell   crown
# paper   fell   Up
# paper   fell   home
# paper   fell   As
# paper   fell   head
# paper   fell   vinegar
# paper   fell   paper
# paper   broke   Jack
# paper   broke   Jill
# paper   broke   hill
# paper   broke   pail
# paper   broke   water
# paper   broke   crown
# paper   broke   Up
# paper   broke   home
# paper   broke   As
# paper   broke   head
# paper   broke   vinegar
# paper   broke   paper
# paper   came   Jack
# paper   came   Jill
# paper   came   hill
# paper   came   pail
# paper   came   water
# paper   came   crown
# paper   came   Up
# paper   came   home
# paper   came   As
# paper   came   head
# paper   came   vinegar
# paper   came   paper
# paper   tumbling   Jack
# paper   tumbling   Jill
# paper   tumbling   hill
# paper   tumbling   pail
# paper   tumbling   water
# paper   tumbling   crown
# paper   tumbling   Up
# paper   tumbling   home
# paper   tumbling   As
# paper   tumbling   head
# paper   tumbling   vinegar
# paper   tumbling   paper
# paper   got   Jack
# paper   got   Jill
# paper   got   hill
# paper   got   pail
# paper   got   water
# paper   got   crown
# paper   got   Up
# paper   got   home
# paper   got   As
# paper   got   head
# paper   got   vinegar
# paper   got   paper
# paper   did   Jack
# paper   did   Jill
# paper   did   hill
# paper   did   pail
# paper   did   water
# paper   did   crown
# paper   did   Up
# paper   did   home
# paper   did   As
# paper   did   head
# paper   did   vinegar
# paper   did   paper
# paper   caper   Jack
# paper   caper   Jill
# paper   caper   hill
# paper   caper   pail
# paper   caper   water
# paper   caper   crown
# paper   caper   Up
# paper   caper   home
# paper   caper   As
# paper   caper   head
# paper   caper   vinegar
# paper   caper   paper
# paper   bed   Jack
# paper   bed   Jill
# paper   bed   hill
# paper   bed   pail
# paper   bed   water
# paper   bed   crown
# paper   bed   Up
# paper   bed   home
# paper   bed   As
# paper   bed   head
# paper   bed   vinegar
# paper   bed   paper
# paper   mend   Jack
# paper   mend   Jill
# paper   mend   hill
# paper   mend   pail
# paper   mend   water
# paper   mend   crown
# paper   mend   Up
# paper   mend   home
# paper   mend   As
# paper   mend   head
# paper   mend   vinegar
# paper   mend   paper

# %% [markdown]
# To represent the words as unqiue vectors in a quantum state-space, we define each vector as a unique qubit index, wherein a two-way mapping exists between the word and the index. This simplifies life for us later, as we map the data into the quantum state-space, and figure out the result of the computation upon completion.

# %%
# Maps the unique string in each respective space to a binary basis number for qubit representation
def mapNameToBinaryBasis(words):
    verbMap = {}
    nounMap = {}
    for i,v in enumerate(words['nouns']):
        #Perform two-way mapping for bin to value and value to bin
        nounMap.update({v:format(i,'b').zfill(num_q_n)})
        nounMap.update({format(i,'b').zfill(num_q_n):v})

    for i,v in enumerate(words['verbs']):
        verbMap.update({v:format(i,'b').zfill(num_q_v)})
        verbMap.update({format(i,'b').zfill(num_q_v):v})
        
    return (nounMap, verbMap)

# %%
nMap,vMap = mapNameToBinaryBasis(words)

# %%
nMap
# Out:
# {'Jack': '0000',
#  '0000': 'Jack',
#  'Jill': '0001',
#  '0001': 'Jill',
#  'hill': '0010',
#  '0010': 'hill',
#  'pail': '0011',
#  '0011': 'pail',
#  'water': '0100',
#  '0100': 'water',
#  'crown': '0101',
#  '0101': 'crown',
#  'Up': '0110',
#  '0110': 'Up',
#  'home': '0111',
#  '0111': 'home',
#  'As': '1000',
#  '1000': 'As',
#  'head': '1001',
#  '1001': 'head',
#  'vinegar': '1010',
#  '1010': 'vinegar',
#  'paper': '1011',
#  '1011': 'paper'}

# %%
vMap
# Out:
# {'went': '0000',
#  '0000': 'went',
#  'fetch': '0001',
#  '0001': 'fetch',
#  'fell': '0010',
#  '0010': 'fell',
#  'broke': '0011',
#  '0011': 'broke',
#  'came': '0100',
#  '0100': 'came',
#  'tumbling': '0101',
#  '0101': 'tumbling',
#  'got': '0110',
#  '0110': 'got',
#  'did': '0111',
#  '0111': 'did',
#  'caper': '1000',
#  '1000': 'caper',
#  'bed': '1001',
#  '1001': 'bed',
#  'mend': '1010',
#  '1010': 'mend'}

# %% [markdown]
# # Prepare quantum states

# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, \
        execute, QuantumCircuit, execute, Aer, IBMQ, compile
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import quantum_info as qi
from qiskit import BasicAer as ba

# %%
#Create the required circuit to represent the data
qreg_n0 = QuantumRegister(num_q_n);
qreg_v = QuantumRegister(num_q_v);
qreg_n1 = QuantumRegister(num_q_n);

# $|1\rangle$ measurement indicates a value has been observed (true), 
# and a $|0\rangle$ indicates no observation (false)
qreg_TF = QuantumRegister(1);

#Results register for measuring the final states
c_q_n0 = ClassicalRegister(num_q_n);
c_q_v = ClassicalRegister(num_q_v); 
c_q_n1 = ClassicalRegister(num_q_n); 

c_q_TF = ClassicalRegister(1); 

circ = QuantumCircuit(qreg_n0, qreg_v, qreg_n1, c_q_n0, c_q_v, c_q_n1, qreg_TF, c_q_TF);

circ0 = QuantumCircuit(qreg_n0);
circ1 = QuantumCircuit(qreg_n1);

# %%
circ.draw()
# Out:
# <pre style="word-wrap: normal;white-space: pre;line-height: 15px;">
# q0_0: |0>
#
# q0_1: |0>
#
# q0_2: |0>
#
# q0_3: |0>
#
# q1_0: |0>
#
# q1_1: |0>
#
# q1_2: |0>
#
# q1_3: |0>
#
# q2_0: |0>
#
# q2_1: |0>
#
# q2_2: |0>
#
# q2_3: |0>
#
# q3_0: |0>
#
#  c0_0: 0
#
#  c0_1: 0
#
#  c0_2: 0
#
#  c0_3: 0
#
#  c1_0: 0
#
#  c1_1: 0
#
#  c1_2: 0
#
#  c1_3: 0
#
#  c2_0: 0
#
#  c2_1: 0
#
#  c2_2: 0
#
#  c2_3: 0
#
#  c3_0: 0
#          </pre>

# %% [markdown]
# To create the appropriate states, we must define the required superposition states necessary to represent the meaning. Mapping the binary strings to superposition states via operations will be the next step.
#
# As a quick aside, let us examine the case of:
# $$
# \begin{pmatrix}
# \textrm{Bill} \\
# \textrm{Mark}
# \end{pmatrix}
# \otimes
# \begin{pmatrix}
# \textrm{loves} \\
# \textrm{hates}
# \end{pmatrix}
# \otimes
# \begin{pmatrix}
# \textrm{cake} \\
# \textrm{fish}
# \end{pmatrix}
# %\otimes
# %\begin{pmatrix}
# %\textrm{True} \\
# %\textrm{False}
# %\end{pmatrix}
# $$
#
# We wish to examine and test the sentences: "Bill hates fish, but Mark likes fish". The state that would encode the above information, assuming binary indexing for each qubit is: $\vert \Psi \rangle = (1/d)*(\vert0\rangle\vert1\rangle\vert1\rangle + \vert1\rangle\vert0\rangle\vert1\rangle)$, where $d$ provides normalisation. In this instance we may pose a question: "Does Bill love fish?". While we can achieve a result with this, it can be noted that the resulting overlap (upon simplification to conj(Bill loves fish)) gives us a scalar value immediately. Instead, what if we want to return the result in a state itself? In this instance it can be useful to include an additional qubit to track the result of the outcome, such as $|0 \rangle$ for false, and $|1\rangle$ for true (or somewhere in between for a more nuanced result). Our tensor state-space now becomes:
#
# $$
# \begin{pmatrix}
# \textrm{Bill} \\
# \textrm{Mark}
# \end{pmatrix}
# \otimes
# \begin{pmatrix}
# \textrm{loves} \\
# \textrm{hates}
# \end{pmatrix}
# \otimes
# \begin{pmatrix}
# \textrm{cake} \\
# \textrm{fish}
# \end{pmatrix}
# \otimes
# \begin{pmatrix}
# \textrm{True} \\
# \textrm{False}
# \end{pmatrix}
# $$
#
# $\vert \Psi^{\prime} \rangle = (1/d)*(\vert0\rangle\vert1\rangle\vert1\rangle\vert1\rangle + \vert1\rangle\vert0\rangle\vert1\rangle\vert1\rangle)$. As such, we may perform a projective measurement on first 3 qubits of our resulting state, and be left with a single qubit encoding the result of our question ('Bill loves fish == True' could be the interpretation in this instance).
#
# As this will destroy the superposition we began with, if we have a method to retrieve the required data from RAM and encode it into a readable state, it may allow us to pose repeated questions. Additionally, methods exist for returning the overlap of a given question with the entire register, returning the largest overlapping state to our problem.

# %%
num_samples = 1000

circ.measure(qreg_n0, c_q_n0)
circ.measure(qreg_v, c_q_v)
circ.measure(qreg_n1, c_q_n1)

backend = Aer.get_backend('qasm_simulator')
qobj = compile(circ, backend, shots=num_samples)
job = backend.run(qobj)
result = job.result()
counts = result.get_counts()
print(counts)

# %%
#Demonstration of fidelity calculation from state-vector values
test_vec = [0.5]*4
qr = QuantumRegister(2, "qr")
qc = QuantumCircuit(qr)
qc.initialize(test_vec, [qr[0], qr[1]])
job = execute(qc, ba.get_backend('statevector_simulator'))
result = job.result()
statevector = result.get_statevector()
fidelity = state_fidelity(statevector, test_vec)

print(fidelity)

# %%
circ0.z(qreg_n0[0])
circ0.x(qreg_n0[1])
job0 = execute(circ0, BasicAer.get_backend('statevector_simulator'))

circ1.x(qreg_n1[0])
circ1.z(qreg_n1[1])
job1 = execute(circ1, BasicAer.get_backend('statevector_simulator'))

# %%
result0 = job0.result()
result1 = job1.result()
statevector0 = result0.get_statevector()
statevector1 = result1.get_statevector()

# %%
print(statevector0)
print(statevector1)
np.abs(np.dot(np.conj(statevector1),statevector0))**2

# %%
qi.state_fidelity(statevector0, statevector1)
